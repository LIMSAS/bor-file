# %%
import bor
bor_file = bor.read('../tests/data/59650240611100849D.bor')

# %%
print(bor_file.description_xml)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <description xmlns="http://www.lim.eu/description" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:schemaLocation="http://www.lim.eu/description description.xsd">
# 	<filename>59650240611100849D</filename>
# 	<creation>2024-06-11T10:08:49-05:00</creation>
# 	<modification>2024-06-11T10:21:29-05:00</modification>
# 	<project_ref>LIM</project_ref>
# 	<borehole_ref>TEST HOLE 1</borehole_ref>
# 	<position>
# 		<longitude unit="degree">-97.6196289</longitude>
# 		<latitude unit="degree">38.8504295</latitude>
# 		<altitude unit="m">378.000000</altitude>
# 		<epv unit="m">655.35</epv>
# 		<eph unit="m">655.35</eph>
# 	</position>
# 	<cell>
# 		<mcc>310</mcc>
# 		<mnc>260</mnc>
# 		<cellid>0073BD02</cellid>
# 		<lac>0000A5ED</lac>
# 	</cell>
# 	<operator>LIM</operator>
# 	<device>
# 		<serial>59650</serial>
# 		<version>1.1</version>
# 		<build>20240408</build>
# 	</device>
# 	<drilling>
# 		<method>DRLMTD_RTR</method>
# 		<tool_diameter unit="inch">3.62</tool_diameter>
# 		<fluid>DRLFLD_WTR</fluid>
# 		<bit_mass unit="lb">0</bit_mass>
# 		<rod_mass unit="lb">0</rod_mass>
# 		<rod_length unit="ft">5</rod_length>
# 		<thrust_area unit="ft2">0</thrust_area>
# 		<holdback_area unit="ft2">0</holdback_area>
# 		<torque_factor>0.00</torque_factor>
# 	</drilling>
# 	<convention version="1.1">
# 		<parameters phase="DRILL">
# 			<effective_duration unit="s">282.90</effective_duration>
# 			<logfile>data.nc</logfile>
# 		</parameters>
# 	</convention>
# </description>

# %%
bor_file.domain
# Out:
# 'DRILLING PARAMETERS'

# %%
bor_file.description['borehole_ref']
# Out:
# 'TEST HOLE 1'

# %%
bor_file.description['drilling']['method']
# Out:
# 'DRLMTD_RTR'

# %%
bor_file.data
# Out:
#                  DEPTH          AS    RV  EVP  EVR         TP         IP  \
# time
# 0.000000      0.000000   76.099998   0.0  0.0  0.0   0.100000  21.100000
# 2.800000      0.020000   19.900000   0.0  0.0  0.0  24.500000  21.100000
# 3.000000      0.030000  278.899994   0.0  0.0  0.0  24.500000  21.100000
# 3.200000      0.050000  291.500000   0.0  0.0  0.0  24.500000  20.799999
# 3.400000      0.060000  253.500000   0.0  0.0  0.0  25.700001  20.600000
# ...                ...         ...   ...  ...  ...        ...        ...
# 1220.599976  20.290001   47.500000  22.0  0.0  0.0  34.299999  20.600000
# 1221.599976  20.299999   38.000000  22.0  0.0  0.0  34.299999  20.600000
# 1222.599976  20.309999   40.599998  55.0  0.0  0.0  34.299999  21.100000
# 1223.800049  20.330000   95.099998  11.0  0.0  0.0  31.799999  17.299999
# 1224.599976  20.350000   93.000000   0.0  0.0  0.0  69.699997  16.500000
#
#                     TQ
# time
# 0.000000      0.100000
# 2.800000     14.700000
# 3.000000     14.700000
# 3.200000     14.700000
# 3.400000     17.200001
# ...                ...
# 1220.599976  40.400002
# 1221.599976  36.700001
# 1222.599976  46.500000
# 1223.800049  42.799999
# 1224.599976  25.700001
#
# [1492 rows x 8 columns]

# %%
bor_file.data.describe()
# Out:
#              DEPTH           AS           RV     EVP     EVR           TP  \
# count  1492.000000  1492.000000  1492.000000  1492.0  1492.0  1492.000000
# mean      9.938352   109.104691    41.548927     0.0     0.0    61.155632
# std       5.857210    79.709251    62.754272     0.0     0.0    14.612050
# min       0.000000     0.700000     0.000000     0.0     0.0     0.100000
# 25%       4.957500    80.300003     8.000000     0.0     0.0    66.000000
# 50%       9.770000   101.400002    31.000000     0.0     0.0    67.199997
# 75%      14.622500   114.099998    59.000000     0.0     0.0    68.500000
# max      20.350000   735.200012  1653.000000     0.0     0.0    70.900002
#
#                 IP           TQ
# count  1492.000000  1492.000000
# mean     19.434317    44.119774
# std       1.705973    10.935656
# min      12.200000     0.100000
# 25%      19.700001    36.700001
# 50%      20.000000    42.799999
# 75%      20.200001    47.700001
# max      21.799999   134.399994

# %%
bor_file.data.loc[:1]
# Out:
#       DEPTH         AS   RV  EVP  EVR   TP    IP   TQ
# time
# 0.0     0.0  76.099998  0.0  0.0  0.0  0.1  21.1  0.1

# %%
bor_file.data.loc[0, 'DEPTH'] = 0.01

# %%
bor_file.data.loc[:1]
# Out:
#       DEPTH         AS   RV  EVP  EVR   TP    IP   TQ
# time
# 0.0    0.01  76.099998  0.0  0.0  0.0  0.1  21.1  0.1

# %%
import matplotlib.pyplot as plt

# %%
df = bor_file.data.round({"DEPTH":2}).set_index('DEPTH')
df
# Out:
#                AS    RV  EVP  EVR         TP         IP         TQ
# DEPTH
# 0.01    76.099998   0.0  0.0  0.0   0.100000  21.100000   0.100000
# 0.02    19.900000   0.0  0.0  0.0  24.500000  21.100000  14.700000
# 0.03   278.899994   0.0  0.0  0.0  24.500000  21.100000  14.700000
# 0.05   291.500000   0.0  0.0  0.0  24.500000  20.799999  14.700000
# 0.06   253.500000   0.0  0.0  0.0  25.700001  20.600000  17.200001
# ...           ...   ...  ...  ...        ...        ...        ...
# 20.29   47.500000  22.0  0.0  0.0  34.299999  20.600000  40.400002
# 20.30   38.000000  22.0  0.0  0.0  34.299999  20.600000  36.700001
# 20.31   40.599998  55.0  0.0  0.0  34.299999  21.100000  46.500000
# 20.33   95.099998  11.0  0.0  0.0  31.799999  17.299999  42.799999
# 20.35   93.000000   0.0  0.0  0.0  69.699997  16.500000  25.700001
#
# [1492 rows x 7 columns]

# %%
df.plot.area(figsize=(16, 6), y=['AS', 'TQ', 'TP'], subplots=True)
# Out:
# array([<Axes: xlabel='DEPTH'>, <Axes: xlabel='DEPTH'>,
#        <Axes: xlabel='DEPTH'>], dtype=object)
